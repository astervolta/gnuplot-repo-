# %%
# installing dependencies
#
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# read in CSV file and turn into dataframe
#
phase_diagrams4 = pd.read_csv ("4-phase-csv.csv")
df = pd.DataFrame(phase_diagrams4)
df
# Out:
#    Potential dG   1-OH     1-O  1/2-O   1/2-OH  bare
# 0           0.0  1.930  5.3340   1.301  0.2969     0
# 1           1.6 -1.269 -1.0650  -1.898 -1.3030     0
# 2           0.0  1.409  4.9310   1.280  0.2333     0
# 3           1.6 -1.790 -1.4680  -1.919 -1.3660     0
# 4           0.0  1.548  6.1430   1.927  0.6491     0
# 5           1.6 -1.651 -0.2562  -1.272 -1.9500     0
# 6           0.0  1.104  5.5150   1.337  0.3490     0
# 7           1.6 -2.095 -0.8841  -1.862 -1.2500     0

# %%
#select desired rows
subset= df.iloc[0:2]
subset
# Out:
#    Potential dG   1-OH    1-O  1/2-O   1/2-OH  bare
# 0           0.0  1.930  5.334   1.301  0.2969     0
# 1           1.6 -1.269 -1.065  -1.898 -1.3030     0

# %%
title1 = input('title: ')
# Out:
# title: Phase Diagram (0,3)

# %%
#plot
#
ax= subset.plot(x='Potential dG', figsize=(14,7))
ax.set(title= title1, xlabel='U (V)', ylabel='dG (eV)')
ax.grid()

# %% [markdown]
# The End ✨👀👍🏽
#
# Scipted by AV
